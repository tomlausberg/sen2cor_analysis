# %%
import os
from pathlib import Path
import pandas as pd

# %%
out_file = Path(r"C:\Users\tlaus\Documents\local\semester_thesis\sen2cor_analysis\outputs\sen2cor_sn7_with_mods_roi_min_errors.txt")

# read output file line by line
with open(out_file, "r") as f:
    lines = f.readlines()

data = []
for line in lines:
    if line.startswith("Running sen2cor for"):
        print(line)
        current_label = line.split("for ")[-1].replace("\n", "")
        print(current_label)
        location, mod = current_label.replace(" ","").split(":")

    if "Application terminated successfully" in line:
        data.append(
            {
                "location": location,
                "mod": mod,
                "success": True
            }
        )

    elif "Application terminated with at least one error" in line:
        data.append(
            {
                "location": location,
                "mod": mod,
                "success": False
            }
        )
df = pd.DataFrame(data)
# Out:
# Running sen2cor for 0357E: FLAG_WV_OFF
#
# 0357E: FLAG_WV_OFF
# Running sen2cor for 0368E: FLAG_WV_OFF
#
# 0368E: FLAG_WV_OFF
# Running sen2cor for 0434E: FLAG_WV_OFF
#
# 0434E: FLAG_WV_OFF
# Running sen2cor for 0487E: FLAG_WV_OFF
#
# 0487E: FLAG_WV_OFF
# Running sen2cor for 0566E: FLAG_WV_OFF
#
# 0566E: FLAG_WV_OFF
# Running sen2cor for 0571E: FLAG_WV_OFF
#
# 0571E: FLAG_WV_OFF
# Running sen2cor for 0586E: FLAG_WV_OFF
#
# 0586E: FLAG_WV_OFF
# Running sen2cor for 0331E: FLAG_CIRRUS_OFF
#
# 0331E: FLAG_CIRRUS_OFF
# Running sen2cor for 0357E: FLAG_CIRRUS_OFF
#
# 0357E: FLAG_CIRRUS_OFF
# Running sen2cor for 0368E: FLAG_CIRRUS_OFF
#
# 0368E: FLAG_CIRRUS_OFF
# Running sen2cor for 0434E: FLAG_CIRRUS_OFF
#
# 0434E: FLAG_CIRRUS_OFF
# Running sen2cor for 0487E: FLAG_CIRRUS_OFF
#
# 0487E: FLAG_CIRRUS_OFF
# Running sen2cor for 0566E: FLAG_CIRRUS_OFF
#
# 0566E: FLAG_CIRRUS_OFF
# Running sen2cor for 0571E: FLAG_CIRRUS_OFF
#
# 0571E: FLAG_CIRRUS_OFF
# Running sen2cor for 0586E: FLAG_CIRRUS_OFF
#
# 0586E: FLAG_CIRRUS_OFF
# Running sen2cor for 0331E: FLAG_BRDF_1
#
# 0331E: FLAG_BRDF_1
# Running sen2cor for 0357E: FLAG_BRDF_1
#
# 0357E: FLAG_BRDF_1
# Running sen2cor for 0368E: FLAG_BRDF_1
#
# 0368E: FLAG_BRDF_1
# Running sen2cor for 0434E: FLAG_BRDF_1
#
# 0434E: FLAG_BRDF_1
# Running sen2cor for 0487E: FLAG_BRDF_1
#
# 0487E: FLAG_BRDF_1
# Running sen2cor for 0566E: FLAG_BRDF_1
#
# 0566E: FLAG_BRDF_1
# Running sen2cor for 0571E: FLAG_BRDF_1
#
# 0571E: FLAG_BRDF_1
# Running sen2cor for 0586E: FLAG_BRDF_1
#
# 0586E: FLAG_BRDF_1
# Running sen2cor for 0331E: FLAG_BRDF_2
#
# 0331E: FLAG_BRDF_2
# Running sen2cor for 0357E: FLAG_BRDF_2
#
# 0357E: FLAG_BRDF_2
# Running sen2cor for 0368E: FLAG_BRDF_2
#
# 0368E: FLAG_BRDF_2
# Running sen2cor for 0434E: FLAG_BRDF_2
#
# 0434E: FLAG_BRDF_2
# Running sen2cor for 0487E: FLAG_BRDF_2
#
# 0487E: FLAG_BRDF_2
# Running sen2cor for 0566E: FLAG_BRDF_2
#
# 0566E: FLAG_BRDF_2
# Running sen2cor for 0571E: FLAG_BRDF_2
#
# 0571E: FLAG_BRDF_2
# Running sen2cor for 0586E: FLAG_BRDF_2
#
# 0586E: FLAG_BRDF_2
# Running sen2cor for 0331E: CALIB_VISIBILITY_20
#
# 0331E: CALIB_VISIBILITY_20
# Running sen2cor for 0357E: CALIB_VISIBILITY_20
#
# 0357E: CALIB_VISIBILITY_20
# Running sen2cor for 0368E: CALIB_VISIBILITY_20
#
# 0368E: CALIB_VISIBILITY_20
# Running sen2cor for 0434E: CALIB_VISIBILITY_20
#
# 0434E: CALIB_VISIBILITY_20
# Running sen2cor for 0487E: CALIB_VISIBILITY_20
#
# 0487E: CALIB_VISIBILITY_20
# Running sen2cor for 0566E: CALIB_VISIBILITY_20
#
# 0566E: CALIB_VISIBILITY_20
# Running sen2cor for 0571E: CALIB_VISIBILITY_20
#
# 0571E: CALIB_VISIBILITY_20
# Running sen2cor for 0586E: CALIB_VISIBILITY_20
#
# 0586E: CALIB_VISIBILITY_20
# Running sen2cor for 0331E: CALIB_VISIBILITY_80
#
# 0331E: CALIB_VISIBILITY_80
# Running sen2cor for 0357E: CALIB_VISIBILITY_80
#
# 0357E: CALIB_VISIBILITY_80
# Running sen2cor for 0368E: CALIB_VISIBILITY_80
#
# 0368E: CALIB_VISIBILITY_80
# Running sen2cor for 0434E: CALIB_VISIBILITY_80
#
# 0434E: CALIB_VISIBILITY_80
# Running sen2cor for 0487E: CALIB_VISIBILITY_80
#
# 0487E: CALIB_VISIBILITY_80
# Running sen2cor for 0566E: CALIB_VISIBILITY_80
#
# 0566E: CALIB_VISIBILITY_80
# Running sen2cor for 0571E: CALIB_VISIBILITY_80
#
# 0571E: CALIB_VISIBILITY_80
# Running sen2cor for 0586E: CALIB_VISIBILITY_80
#
# 0586E: CALIB_VISIBILITY_80
# Running sen2cor for 0331E: CALIB_VISIBILITY_120
#
# 0331E: CALIB_VISIBILITY_120
# Running sen2cor for 0357E: CALIB_VISIBILITY_120
#
# 0357E: CALIB_VISIBILITY_120
# Running sen2cor for 0368E: CALIB_VISIBILITY_120
#
# 0368E: CALIB_VISIBILITY_120
# Running sen2cor for 0434E: CALIB_VISIBILITY_120
#
# 0434E: CALIB_VISIBILITY_120
# Running sen2cor for 0487E: CALIB_VISIBILITY_120
#
# 0487E: CALIB_VISIBILITY_120
# Running sen2cor for 0566E: CALIB_VISIBILITY_120
#
# 0566E: CALIB_VISIBILITY_120
# Running sen2cor for 0571E: CALIB_VISIBILITY_120
#
# 0571E: CALIB_VISIBILITY_120
# Running sen2cor for 0586E: CALIB_VISIBILITY_120
#
# 0586E: CALIB_VISIBILITY_120
# Running sen2cor for 0331E: class_NO_DATA
#
# 0331E: class_NO_DATA
# Running sen2cor for 0357E: class_NO_DATA
#
# 0357E: class_NO_DATA
# Running sen2cor for 0368E: class_NO_DATA
#
# 0368E: class_NO_DATA
# Running sen2cor for 0434E: class_NO_DATA
#
# 0434E: class_NO_DATA
# Running sen2cor for 0487E: class_NO_DATA
#
# 0487E: class_NO_DATA
# Running sen2cor for 0566E: class_NO_DATA
#
# 0566E: class_NO_DATA
# Running sen2cor for 0571E: class_NO_DATA
#
# 0571E: class_NO_DATA
# Running sen2cor for 0586E: class_NO_DATA
#
# 0586E: class_NO_DATA
# Running sen2cor for 0331E: class_CLOUD_SHADOWS
#
# 0331E: class_CLOUD_SHADOWS
# Running sen2cor for 0357E: class_CLOUD_SHADOWS
#
# 0357E: class_CLOUD_SHADOWS
# Running sen2cor for 0368E: class_CLOUD_SHADOWS
#
# 0368E: class_CLOUD_SHADOWS
# Running sen2cor for 0434E: class_CLOUD_SHADOWS
#
# 0434E: class_CLOUD_SHADOWS
# Running sen2cor for 0487E: class_CLOUD_SHADOWS
#
# 0487E: class_CLOUD_SHADOWS
# Running sen2cor for 0566E: class_CLOUD_SHADOWS
#
# 0566E: class_CLOUD_SHADOWS
# Running sen2cor for 0571E: class_CLOUD_SHADOWS
#
# 0571E: class_CLOUD_SHADOWS
# Running sen2cor for 0586E: class_CLOUD_SHADOWS
#
# 0586E: class_CLOUD_SHADOWS
# Running sen2cor for 0331E: class_VEGETATION
#
# 0331E: class_VEGETATION
# Running sen2cor for 0357E: class_VEGETATION
#
# 0357E: class_VEGETATION
# Running sen2cor for 0368E: class_VEGETATION
#
# 0368E: class_VEGETATION
# Running sen2cor for 0434E: class_VEGETATION
#
# 0434E: class_VEGETATION
# Running sen2cor for 0487E: class_VEGETATION
#
# 0487E: class_VEGETATION
# Running sen2cor for 0566E: class_VEGETATION
#
# 0566E: class_VEGETATION
# Running sen2cor for 0571E: class_VEGETATION
#
# 0571E: class_VEGETATION
# Running sen2cor for 0586E: class_VEGETATION
#
# 0586E: class_VEGETATION
# Running sen2cor for 0331E: class_NOT_VEGETATED
#
# 0331E: class_NOT_VEGETATED
# Running sen2cor for 0357E: class_NOT_VEGETATED
#
# 0357E: class_NOT_VEGETATED
# Running sen2cor for 0368E: class_NOT_VEGETATED
#
# 0368E: class_NOT_VEGETATED
# Running sen2cor for 0434E: class_NOT_VEGETATED
#
# 0434E: class_NOT_VEGETATED
# Running sen2cor for 0487E: class_NOT_VEGETATED
#
# 0487E: class_NOT_VEGETATED
# Running sen2cor for 0566E: class_NOT_VEGETATED
#
# 0566E: class_NOT_VEGETATED
# Running sen2cor for 0571E: class_NOT_VEGETATED
#
# 0571E: class_NOT_VEGETATED
# Running sen2cor for 0586E: class_NOT_VEGETATED
#
# 0586E: class_NOT_VEGETATED
# Running sen2cor for 0331E: class_WATER
#
# 0331E: class_WATER
# Running sen2cor for 0357E: class_WATER
#
# 0357E: class_WATER
# Running sen2cor for 0368E: class_WATER
#
# 0368E: class_WATER
# Running sen2cor for 0434E: class_WATER
#
# 0434E: class_WATER
# Running sen2cor for 0487E: class_WATER
#
# 0487E: class_WATER
# Running sen2cor for 0566E: class_WATER
#
# 0566E: class_WATER
# Running sen2cor for 0571E: class_WATER
#
# 0571E: class_WATER
# Running sen2cor for 0586E: class_WATER
#
# 0586E: class_WATER
# Running sen2cor for 0331E: class_UNCLASSIFIED
#
# 0331E: class_UNCLASSIFIED
# Running sen2cor for 0357E: class_UNCLASSIFIED
#
# 0357E: class_UNCLASSIFIED
# Running sen2cor for 0368E: class_UNCLASSIFIED
#
# 0368E: class_UNCLASSIFIED
# Running sen2cor for 0434E: class_UNCLASSIFIED
#
# 0434E: class_UNCLASSIFIED
# Running sen2cor for 0487E: class_UNCLASSIFIED
#
# 0487E: class_UNCLASSIFIED
# Running sen2cor for 0566E: class_UNCLASSIFIED
#
# 0566E: class_UNCLASSIFIED
# Running sen2cor for 0571E: class_UNCLASSIFIED
#
# 0571E: class_UNCLASSIFIED
# Running sen2cor for 0586E: class_UNCLASSIFIED
#
# 0586E: class_UNCLASSIFIED
# Running sen2cor for 0331E: class_CLOUD_MEDIUM_PROBABILITY
#
# 0331E: class_CLOUD_MEDIUM_PROBABILITY
# Running sen2cor for 0357E: class_CLOUD_MEDIUM_PROBABILITY
#
# 0357E: class_CLOUD_MEDIUM_PROBABILITY
# Running sen2cor for 0368E: class_CLOUD_MEDIUM_PROBABILITY
#
# 0368E: class_CLOUD_MEDIUM_PROBABILITY
# Running sen2cor for 0434E: class_CLOUD_MEDIUM_PROBABILITY
#
# 0434E: class_CLOUD_MEDIUM_PROBABILITY
# Running sen2cor for 0487E: class_CLOUD_MEDIUM_PROBABILITY
#
# 0487E: class_CLOUD_MEDIUM_PROBABILITY
# Running sen2cor for 0566E: class_CLOUD_MEDIUM_PROBABILITY
#
# 0566E: class_CLOUD_MEDIUM_PROBABILITY
# Running sen2cor for 0571E: class_CLOUD_MEDIUM_PROBABILITY
#
# 0571E: class_CLOUD_MEDIUM_PROBABILITY
# Running sen2cor for 0586E: class_CLOUD_MEDIUM_PROBABILITY
#
# 0586E: class_CLOUD_MEDIUM_PROBABILITY
# Running sen2cor for 0331E: class_CLOUD_HIGH_PROBABILITY
#
# 0331E: class_CLOUD_HIGH_PROBABILITY
# Running sen2cor for 0357E: class_CLOUD_HIGH_PROBABILITY
#
# 0357E: class_CLOUD_HIGH_PROBABILITY
# Running sen2cor for 0368E: class_CLOUD_HIGH_PROBABILITY
#
# 0368E: class_CLOUD_HIGH_PROBABILITY
# Running sen2cor for 0434E: class_CLOUD_HIGH_PROBABILITY
#
# 0434E: class_CLOUD_HIGH_PROBABILITY
# Running sen2cor for 0487E: class_CLOUD_HIGH_PROBABILITY
#
# 0487E: class_CLOUD_HIGH_PROBABILITY
# Running sen2cor for 0566E: class_CLOUD_HIGH_PROBABILITY
#
# 0566E: class_CLOUD_HIGH_PROBABILITY
# Running sen2cor for 0571E: class_CLOUD_HIGH_PROBABILITY
#
# 0571E: class_CLOUD_HIGH_PROBABILITY
# Running sen2cor for 0586E: class_CLOUD_HIGH_PROBABILITY
#
# 0586E: class_CLOUD_HIGH_PROBABILITY
# Running sen2cor for 0331E: class_THIN_CIRRUS
#
# 0331E: class_THIN_CIRRUS
# Running sen2cor for 0357E: class_THIN_CIRRUS
#
# 0357E: class_THIN_CIRRUS
# Running sen2cor for 0368E: class_THIN_CIRRUS
#
# 0368E: class_THIN_CIRRUS
# Running sen2cor for 0434E: class_THIN_CIRRUS
#
# 0434E: class_THIN_CIRRUS
# Running sen2cor for 0487E: class_THIN_CIRRUS
#
# 0487E: class_THIN_CIRRUS
# Running sen2cor for 0566E: class_THIN_CIRRUS
#
# 0566E: class_THIN_CIRRUS
# Running sen2cor for 0571E: class_THIN_CIRRUS
#
# 0571E: class_THIN_CIRRUS
# Running sen2cor for 0586E: class_THIN_CIRRUS
#
# 0586E: class_THIN_CIRRUS
# Running sen2cor for 0331E: class_SNOW
#
# 0331E: class_SNOW
# Running sen2cor for 0357E: class_SNOW
#
# 0357E: class_SNOW
# Running sen2cor for 0368E: class_SNOW
#
# 0368E: class_SNOW
# Running sen2cor for 0434E: class_SNOW
#
# 0434E: class_SNOW
# Running sen2cor for 0487E: class_SNOW
#
# 0487E: class_SNOW
# Running sen2cor for 0566E: class_SNOW
#
# 0566E: class_SNOW
# Running sen2cor for 0571E: class_SNOW
#
# 0571E: class_SNOW
# Running sen2cor for 0586E: class_SNOW
#
# 0586E: class_SNOW

# %%
df.sort_values(by=["location", "mod"], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 df.sort_values(by=["location", "mod"], inplace=True)
#
# AttributeError: 'NoneType' object has no attribute 'sort_values'

# %%
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 df.head()
#
# AttributeError: 'NoneType' object has no attribute 'head'
